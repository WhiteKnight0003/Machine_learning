# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - khác với knn của supervised learning
# - đây là bài toán chia ra k nhóm (cum - sao cho các điểm tương đồng với đặc điểm của nhóm đó)
