# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #
# - Nó rất phù hợp cho những bộ dataset tuyến tính (các feature có quan hệ với target)
# - Với những bộ dataset mà không tuyến tính (các feature không có quan hệ với target) hay dataset có outlaier thì performance của chúng khác là tệ

# %% [markdown]
# - Giả sử bạn có 1 biến hay 1 feature và 1 target và từ feature dự đoán ra target
# - trong ví dụ t có 2 cột là salary và experience , từ experience ta cần dự đoán ra salary
#
# - như bạn thấy trong ảnh - ngoài trục x , y có n điểm khác (không gian có n chiều) và nhiệm vụ của bài toán này là làm sao tìm ra đường thẳng y tuyến tính đi qua mặt phẳng chứa n đỉnh này (với khoảng cách từ y đến điểm là nhỏ nhất)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - về mặt lý thuyết mô hình phụ thuộc vào mấy cái hệ số b1, b2,b3 .. và cần chúng là tuyến tính
# - còn về mấy cái biến x1, x2 ngta có thể đặt biến phụ để xử lý
