# %% [markdown]
# # hồi quy đa thức - từ bậc 2 trở lên

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# khi dữ liệu thì phức tạp còn mô hình quá đơn giản , bạn sẽ không thể fix bằng mô hinhg linear regression bình thường 
# khi mô hình bậc 1 không tốt ta có thể nâng nó lên ví dụ bậc 2 , bậc 3

# under fitting : mô hình đơn giản - dữ liệu phức tạp
# over fitting : dữ liệu đơn giản - mô hình phức tạp - tức là fix quá mức có thể dẫn đến sai các điểm sau

# mô hình có độ chính xác cao mà có độ phức tạp lớn  => over fitting  nên phải cân bằng cả 2 yếu tố để độ phức tạp min
