# %% [markdown]
# # Mang tính trả lời khi đi phỏng vấn
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # giảm chiều dữ liệu
# - giảm số dữ liệu rồi ép về 1 trong 2 trường hợp ở trước
# - nhiều - ít data -> nhiều - ít hàng
