# %% [markdown]
# # Term Frequency - Inverse Document Frequency
# - Kỹ thuật gán điểm cho các token
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - Gán điểm dựa trên 2 thành phần TF  và IDF và chúng được tính theo công thức trên

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
ví dụ tính từ best ở các document 
ở dòng 1 : 
    - TF = 1/9 (từ best xuất hiện 1 lần trong 9 từ)
    - IDF = log(4/2) = 1  (ở đây là logarit cơ số 2 ) - chỉ cần tính 1 lần - những cái sau nó cũng sẽ chỉ có IDF như này 
ở dòng 2 : 
    - TF = 1/9 
ở dòng 3 và 4 : TF = 0/9 = 0


* những từ qtrong là những từ phải trung hòa được tỉ lệ TF và IDF
- TF = 0 tức từ đó k xuất hiện 
- IDF = 0  tức ở đâu từ đó cũng xuất hiện
